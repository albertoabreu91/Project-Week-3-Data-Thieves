# %% [markdown]
# # Web Scraping on El Pais
#
# Since El Pais is one of the most read newspaper in the world, we want to look how the refugees topic is covered in this specific newspaper.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url ='https://elpais.com/buscador/?qt=refugiados&sf=0&np=1&bu=ep&of=html'

url2 = 'https://www.lavanguardia.com/search?q=refugiados#gsc.tab=0&gsc.q=refugiados'

# %%
page = requests.get(url2)
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\r\n<html lang="es">\r\n\t<head>\r\n\t<!-- Methode uuid: "45966560-f9cc-11e6-a899-41047b3b6bb8" -->\r\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\r\n<title>B\xc3\xbasqueda</title>\r\n\t\t\t<meta name="twitter:title" content="B\xc3\xbasqueda" />\r\n\t\t<meta property="og:title" content="B\xc3\xbasqueda" data-page-subject="true" />\r\n\t<meta name="description" content="" />\r\n\t<meta name="Keywords" content="\xc3\xbaltima hora, \xc3\xbaltimas noticias, noticias en espanol, al minuto, entretenimiento, videos, Catalunya, Catalu\xc3\xb1a, Espa\xc3\xb1a, deportes, econom\xc3\xada, internacional, internet, noticias, opini\xc3\xb3n, peri\xc3\xb3dico, pol\xc3\xadtica, Barcelona, comunidad, tecnolog\xc3\xada, vanguardia, sucesos, gente, mundo, informaci\xc3\xb3n, participaci\xc3\xb3n" />\r\n\t<meta name="robots" content="index, follow" />\r\n\t<meta name="organization" content="La 
# ...

# %%
news = BeautifulSoup(page.content, 'html.parser')

print(news.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es">
#  <head>
#   <!-- Methode uuid: "45966560-f9cc-11e6-a899-41047b3b6bb8" -->
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title>
#    Búsqueda
#   </title>
#   <meta content="Búsqueda" name="twitter:title"/>
#   <meta content="Búsqueda" data-page-subject="true" property="og:title"/>
#   <meta content="" name="description"/>
#   <meta content="última hora, últimas noticias, noticias en espanol, al minuto, entretenimiento, videos, Catalunya, Cataluña, España, deportes, economía, internacional, internet, noticias, opinión, periódico, política, Barcelona, comunidad, tecnología, vanguardia, sucesos, gente, mundo, información, participación" name="Keywords"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="La Vanguardia S.A" name="organization"/>
#   <link href="https://www.lavanguardia.com/search" rel="canonical"/>
# ...

# %%
soup = BeautifulSoup(page.text, 'html')

# %% [raw]
# soup

# %%
tags = ['a']

text = [element.text for element in elpais_news.find_all(tags)]

text
# Out:
# ['EL PAÍS']

# %%
table = soup.find_all('a', attrs= {'title':"Ver noticia"})

# %%
table
# Out:
# []
