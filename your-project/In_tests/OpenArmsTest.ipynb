# %% [markdown]
# ## Open arms Test in NewsAPI

# %% [markdown]
# https://newsapi.org/docs/client-libraries/python

# %%
from newsapi.newsapi_client import NewsApiClient
import pandas as pd
import pprint

# %%
newsapi = NewsApiClient(api_key='df4e25b616e04799aad77f92817f9fc3') #Ingrid's Token

# %%
sources = newsapi.get_sources()

# %%
sources
# Out:
# {'status': 'ok',
#  'sources': [{'id': 'abc-news',
#    'name': 'ABC News',
#    'description': 'Your trusted source for breaking news, analysis, exclusive interviews, headlines, and videos at ABCNews.com.',
#    'url': 'https://abcnews.go.com',
#    'category': 'general',
#    'language': 'en',
#    'country': 'us'},
#   {'id': 'abc-news-au',
#    'name': 'ABC News (AU)',
#    'description': "Australia's most trusted source of local, national and world news. Comprehensive, independent, in-depth analysis, the latest business, sport, weather and more.",
#    'url': 'http://www.abc.net.au/news',
#    'category': 'general',
#    'language': 'en',
#    'country': 'au'},
#   {'id': 'aftenposten',
#    'name': 'Aftenposten',
#    'description': 'Norges ledende nettavis med alltid oppdaterte nyheter innenfor innenriks, utenriks, sport og kultur.',
#    'url': 'https://www.aftenposten.no',
#    'category': 'general',
#    'language': 'no',
#    'country': 'no'},
# ...

# %%
sources['sources']
# Out:
# [{'id': 'abc-news',
#   'name': 'ABC News',
#   'description': 'Your trusted source for breaking news, analysis, exclusive interviews, headlines, and videos at ABCNews.com.',
#   'url': 'https://abcnews.go.com',
#   'category': 'general',
#   'language': 'en',
#   'country': 'us'},
#  {'id': 'abc-news-au',
#   'name': 'ABC News (AU)',
#   'description': "Australia's most trusted source of local, national and world news. Comprehensive, independent, in-depth analysis, the latest business, sport, weather and more.",
#   'url': 'http://www.abc.net.au/news',
#   'category': 'general',
#   'language': 'en',
#   'country': 'au'},
#  {'id': 'aftenposten',
#   'name': 'Aftenposten',
#   'description': 'Norges ledende nettavis med alltid oppdaterte nyheter innenfor innenriks, utenriks, sport og kultur.',
#   'url': 'https://www.aftenposten.no',
#   'category': 'general',
#   'language': 'no',
#   'country': 'no'},
#  {'id': 'al-jazeera-english',
#   'name': 'Al Jazeera English',
# ...

# %%
sources_df = pd.DataFrame(sources['sources'])

# %%
sources_df
# Out:
#           category country                                        description  \
# 0          general      us  Your trusted source for breaking news, analysi...
# 1          general      au  Australia's most trusted source of local, nati...
# 2          general      no  Norges ledende nettavis med alltid oppdaterte ...
# 3          general      us  News, analysis from the Middle East and worldw...
# 4          general      it  Agenzia ANSA: ultime notizie, foto, video e ap...
# 5         business      sa  ارقام موقع متخصص في متابعة سوق الأسهم السعودي ...
# 6       technology      us  The PC enthusiast's resource. Power users and ...
# 7          general      pk  ARY News is a Pakistani news channel committed...
# 8          general      us  The AP delivers in-depth coverage on the inter...
# 9         business      au  The Australian Financial Review reports the la...
# 10         general      us  Axios are a new media company delivering vital...
# ...

# %% [markdown]
# Let's see how many newspaper categories we have

# %%
categories = set(list(sources_df.category))

# %%
categories
# Out:
# {'business',
#  'entertainment',
#  'general',
#  'health',
#  'science',
#  'sports',
#  'technology'}

# %% [markdown]
# We can drop all the newspaper that are not 'General'.

# %%
sources_df_general = sources_df[sources_df['category']=='general']

# %%
sources_df_general
# Out:
#     category country                                        description  \
# 0    general      us  Your trusted source for breaking news, analysi...
# 1    general      au  Australia's most trusted source of local, nati...
# 2    general      no  Norges ledende nettavis med alltid oppdaterte ...
# 3    general      us  News, analysis from the Middle East and worldw...
# 4    general      it  Agenzia ANSA: ultime notizie, foto, video e ap...
# 7    general      pk  ARY News is a Pakistani news channel committed...
# 8    general      us  The AP delivers in-depth coverage on the inter...
# 10   general      us  Axios are a new media company delivering vital...
# 11   general      gb  Use BBC News for up-to-the-minute news, breaki...
# 13   general      de  Die Seite 1 für aktuelle Nachrichten und Theme...
# 14   general      br  Descubra a seção brasileira da Blasting News, ...
# 17   general      us  Syndicated news and opinion website providing ...
# ...

# %%
sources_df_general.to_csv('newsAPIGeneralSources.csv')

# %%
all_articles = newsapi.get_everything(q='openarms')

table = pd.DataFrame(all_articles)
pprint.pprint(all_articles,indent=2)
# Out:
# { 'articles': [ { 'author': 'F. Q.',
#                   'content': 'Si trova al limite delle acque territoriali '
#                              'italiane, a 12 miglia da Lampedusa la nave Alex '
#                              'di Mediterranea Saving Humans che ieri ha '
#                              'soccorso un gommone in difficoltà con 54 persone '
#                              'a bordo al largo della Libia. Dal governo '
#                              'italiano è arrivato il divieto di … [+9597 '
#                              'chars]',
#                   'description': 'All\'offerta, la ong aveva risposto che "per '
#                                  'le condizioni psicofisiche delle persone a '
#                                  'bordo e le caratteristiche della nave, non '
#                                  'siamo in grado di affrontare la traversata. '
#                                  'Ma siamo disponibili a trasferire i '
# ...

# %%
all_articles = newsapi.get_everything(q='refugees')

table = pd.DataFrame(all_articles)
pprint.pprint(all_articles,indent=2)
# Out:
# { 'articles': [ { 'author': 'Astead W. Herndon',
#                   'content': 'Ekram Elmoge, a 21-year-old who resettled in St. '
#                              'Cloud from Somalia about five years ago, '
#                              'described the city as diversity without '
#                              'inclusion. Ms. Elmoge said she had been harassed '
#                              'by white residents, who have yelled, Go back to '
#                              'your country and Youre here for … [+1877 chars]',
#                   'description': 'As more Somali refugees arrive in St. Cloud, '
#                                  'white anti-immigration activists have '
#                                  'pressed an increasingly explicit anti-Muslim '
#                                  'agenda.',
#                   'publishedAt': '2019-06-20T09:00:08Z',
#                   'source': { 'id': 'the-new-york-times',
#                               'name': 'The New York Times'},
# ...

# %%
all_articles = newsapi.get_everything(q='open arms')

table = pd.DataFrame(all_articles)
pprint.pprint(all_articles,indent=2)
# Out:
# { 'articles': [ { 'author': 'https://www.facebook.com/bbcnews',
#                   'content': 'Image copyrightWiegand Family via CBS NewsImage '
#                              'caption\r\n'
#                              ' Chloe Wiegand, from Indiana, died on Sunday\r\n'
#                              'The family of a toddler who died after falling '
#                              '11 storeys from an open window on a Royal '
#                              'Caribbean cruise ship has blamed the company for '
#                              'the accident.\r\n'
#                              'Chl… [+2313 chars]',
#                   'description': "The family's lawyer says the cruise company "
#                                  'should not have left an open window in a '
#                                  'play area.',
#                   'publishedAt': '2019-07-09T21:12:46Z',
#                   'source': {'id': 'bbc-news', 'name': 'BBC News'},
# ...

# %%
all_articles['articles']
# Out:
# [{'source': {'id': 'bbc-news', 'name': 'BBC News'},
#   'author': 'https://www.facebook.com/bbcnews',
#   'title': "US family blames cruise company for toddler's death",
#   'description': "The family's lawyer says the cruise company should not have left an open window in a play area.",
#   'url': 'https://www.bbc.co.uk/news/world-us-canada-48927911',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/FAC9/production/_107810246_img-3325.jpg',
#   'publishedAt': '2019-07-09T21:12:46Z',
#   'content': 'Image copyrightWiegand Family via CBS NewsImage caption\r\n Chloe Wiegand, from Indiana, died on Sunday\r\nThe family of a toddler who died after falling 11 storeys from an open window on a Royal Caribbean cruise ship has blamed the company for the accident.\r\nChl… [+2313 chars]'},
#  {'source': {'id': 'the-new-york-times', 'name': 'The New York Times'},
#   'author': 'Kurt Streeter',
#   'title': 'Richmond Is at a Crossroads. Will Arthur Ashe Boulevard Point the Way?',
# ...

# %%
open_arms_df = pd.DataFrame(all_articles['articles'])

# %%
open_arms_df.head()
# Out:
#                              author  \
# 0                 Reuters Editorial
# 1  https://www.facebook.com/bbcnews
# 2                    SPIEGEL ONLINE
# 3                     Thomas Wieder
# 4             Anna-Sophie Schneider
#
#                                              content  \
# 0  BERLIN (Reuters) - A spokesman for Germany’s F...
# 1  Media captionThe Sea-Watch 3 has been prevente...
# 2  Liebe Abonnentin, lieber Abonnent, guten Abend...
# 3  Article réservé aux abonnés\r\nLa capitaine du...
# 4  hier finden Sie die wichtigsten Nachrichten de...
#
#                                          description           publishedAt  \
# 0  A spokesman for Germany's Foreign Ministry con...  2019-07-03T12:25:20Z
# 1  It comes as Italy tries to clamp down on migra...  2019-06-28T01:31:49Z
# 2  Liebe Abonnentin, lieber Abonnent, guten Abend...  2019-07-05T16:00:00Z
# 3  La capitaine du « Sea Watch 3 » a été arrêtée ...  2019-07-02T01:13:48Z
# ...

# %%
open_arms_df.dtypes
# Out:
# author         object
# content        object
# description    object
# publishedAt    object
# source         object
# title          object
# url            object
# urlToImage     object
# dtype: object

# %%
open_arms_df['publishedAt'] = pd.to_datetime(open_arms_df['publishedAt'])

# %%
open_arms_df.head()
# Out:
#                              author  \
# 0                 Reuters Editorial
# 1  https://www.facebook.com/bbcnews
# 2                    SPIEGEL ONLINE
# 3                     Thomas Wieder
# 4             Anna-Sophie Schneider
#
#                                              content  \
# 0  BERLIN (Reuters) - A spokesman for Germany’s F...
# 1  Media captionThe Sea-Watch 3 has been prevente...
# 2  Liebe Abonnentin, lieber Abonnent, guten Abend...
# 3  Article réservé aux abonnés\r\nLa capitaine du...
# 4  hier finden Sie die wichtigsten Nachrichten de...
#
#                                          description  \
# 0  A spokesman for Germany's Foreign Ministry con...
# 1  It comes as Italy tries to clamp down on migra...
# 2  Liebe Abonnentin, lieber Abonnent, guten Abend...
# 3  La capitaine du « Sea Watch 3 » a été arrêtée ...
# 4  hier finden Sie die wichtigsten Nachrichten de...
#
#                 publishedAt  \
# 0 2019-07-03 12:25:20+00:00
# 1 2019-06-28 01:31:49+00:00
# ...

# %%
open_arms_df.dtypes
# Out:
# author                      object
# content                     object
# description                 object
# publishedAt    datetime64[ns, UTC]
# source                      object
# title                       object
# url                         object
# urlToImage                  object
# dtype: object

# %%
open_arms_df['source'][5]['id']
# Out:
# 'spiegel-online'

# %% [markdown]
# We should improve the columns on source, since it contains a dictionary inside. We would like to create two columns, one called source_id and the other one source_name. But it should be

# %%
#open_arms_df['source_id'] = open_arms_df['source'][lambda row: row in open_arms_df['source']]['id']

# %%
all_articles = newsapi.get_everything(q='Carola Rackete')

table = pd.DataFrame(all_articles)
pprint.pprint(all_articles,indent=2)
# Out:
# { 'articles': [ { 'author': 'Reuters Editorial',
#                   'content': 'BERLIN (Reuters) - A spokesman for Germany’s '
#                              'Foreign Ministry condemned as wholly '
#                              'unacceptable the kind of online threats and hate '
#                              'speech that led to the German captain of a sea '
#                              'rescue vessel having to hide in a secret '
#                              'location. \r\n'
#                              'Italy’s Interior Minister Ma… [+543 chars]',
#                   'description': "A spokesman for Germany's Foreign Ministry "
#                                  'condemned as wholly unacceptable the kind of '
#                                  'online threats and hate speech that led to '
#                                  'the German captain of a sea rescue vessel '
#                                  'having to hide in a secret location.',
# ...

# %%
all_articles = newsapi.get_everything(q='Sea Watch 3')

table = pd.DataFrame(all_articles)
pprint.pprint(all_articles,indent=2)
# Out:
# { 'articles': [ { 'author': 'Darrell Etherington',
#                   'content': 'SpaceX managed another first for its reusable '
#                              'rocketry efforts during its most recent launch '
#                              'when it caught part of the fairing in a giant '
#                              'net mounted on a boat named ‘Ms. Tree.’ The '
#                              'nosecone component, used to protect the Falcon '
#                              'Heavy’s cargo during its June… [+1868 chars]',
#                   'description': 'SpaceX managed another first for its '
#                                  'reusable rocketry efforts during its most '
#                                  'recent launch when it caught part of the '
#                                  'fairing in a giant net mounted on a boat '
#                                  'named ‘Ms. Tree.’ The nosecone component, '
# ...

# %%
all_articles = newsapi.get_everything(q='Sea Watch 3', sort_by='relevancy', page=2 )

table = pd.DataFrame(all_articles)
pprint.pprint(all_articles,indent=2)
# Out:
# { 'articles': [ { 'author': None,
#                   'content': 'The amount of ice circling Antarctica is '
#                              'suddenly plunging from a record high to record '
#                              'lows, baffling scientists.\r\n'
#                              'Floating ice off the southern continent steadily '
#                              'increased from 1979 and hit a record high in '
#                              '2014. But three years later, the annual average '
#                              'e… [+3295 chars]',
#                   'description': 'Scientists baffled as Antarctic ice hits '
#                                  'record low, wiping out three decades of '
#                                  '‘gains’ Global News The difference covers an '
#                                  'area bigger than the size of Mexico. Losing '
#                                  'that much in just three years “is pretty '
# ...
